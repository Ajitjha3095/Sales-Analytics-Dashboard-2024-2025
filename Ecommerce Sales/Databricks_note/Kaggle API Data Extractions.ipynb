# %%
# %pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import osos.environ['KAGGLE_USERNAME'] = 'Your Username'
os.environ['KAGGLE_KEY'] = 'Your API Key'7'

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

api.dataset_download_files (
    "ajitjha01/sales-dataset",
    path = "/Volumes/main/default/ecommerce_data",
    unzip = True
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from kaggle.api.kaggle_api_extended import KaggleApi
#       2
#       3 api = KaggleApi()
#       4 api.authenticate()
#
# ModuleNotFoundError: No module named 'kaggle'

# %%
import os

print(os.listdir("/tmp/ecommerce"))
# Out:
# ['ECOMMERS SALES.csv']

# %%
df = spark.read.csv("/Volumes/main/default/ecommerce_data/ECOMMERS SALES.csv", header=True, inferSchema=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Order_ID: integer (nullable = true)
#  |-- Order_Date: date (nullable = true)
#  |-- Product_Name: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- Unit_Price: integer (nullable = true)
#  |-- Total_Sales: integer (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Customer_Type: string (nullable = true)
#  |-- Payment_Method: string (nullable = true)

# %%
print(df.count())
# Out:
# 499

# %%
from pyspark.sql.functions import year

final_df.groupBy(
    year("Order_Date").alias("Year")
).count().orderBy("Year").show()
# Out:
# +----+-----+
# |Year|count|
# +----+-----+
# |2022|  324|
# |2023|  452|
# |2024|  225|
# |2025|  364|
# |2026|  135|
# +----+-----+
